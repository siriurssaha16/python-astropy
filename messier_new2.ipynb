# %%
import numpy as np
from astropy import units as u 
# %config InlineBackend.rc = {}
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 
from astropy.io import ascii

# %%
import astropy.coordinates as coord
data = ascii.read("Messier-objects-details-Sheet1-2.csv")

# %%
ra =coord.Angle(data['RA'])
ra.degree
ra = ra.wrap_at(180*u.degree)
dec = coord.Angle(data['DEC']*u.degree)
msize = data['Mag']
Msize = np.array(10**(msize/(-2.5)))*19100

# %%
fig = plt.figure(figsize = (14,12))
ax = fig.add_subplot(111, projection = "mollweide")
ax.scatter(ra.radian, dec.radian, s=Msize)

# %%
t = np.random.rand(110)
fig = plt.figure(figsize = (14,12))
ax = fig.add_subplot(111, projection = "mollweide")
ax.scatter(ra.radian, dec.radian, s=Msize, c=t)

# %%
#function for angular separation 
from astropy.coordinates import SkyCoord 
a0 = ra[0].radian
a1 = ra[1].radian
b0 = dec[0].radian
b1 = dec[1].radian
c1 = SkyCoord(ra = a0*u.degree, dec = b1*u.degree)
c2 = SkyCoord(ra = a1*u.degree, dec = b2*u.degree)
c1.separation(c2).radian
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-97b7dfa075c9> in <module>
#       6 b1 = dec[1].radian
#       7 c1 = SkyCoord(ra = a1*u.degree, dec = b1*u.degree)
# ----> 8 c2 = SkyCoord(ra = a2*u.degree, dec = b2*u.degree)
#       9 c1.separation(c2).radian
#
# NameError: name 'a2' is not defined
